# %% [markdown]
# # Write Virtual Icechunk with VirtualiZarr

# %%
from arraylake import Client
from s3fs import S3FileSystem
from tqdm.notebook import tqdm
from virtualizarr.readers.hdf import HDFVirtualBackend
from virtualizarr import open_virtual_dataset
import xarray as xr
import zarr

# %%
zarr.__version__
# Out:
# '3.0.0b2'

# %%
s3 = S3FileSystem()

base_url = "s3://gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07"
one_day = s3.ls(f"{base_url}/1998/001")
one_day
# Out:
# ['gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S000000-E002959.0000.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S003000-E005959.0030.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S010000-E012959.0060.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S013000-E015959.0090.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S020000-E022959.0120.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S023000-E025959.0150.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S030000-E032959.0180.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S033000-E035959.0210.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S040000-E042959.0240.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S043000-E045959.0270.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S050000-E052959.0300.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S053000-E055959.0330.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S060000-E062959.0360.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S063000-E065959.0390.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S070000-E072959.0420.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S073000-E075959.0450.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S080000-E082959.0480.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S083000-E085959.0510.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S090000-E092959.0540.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S093000-E095959.0570.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S100000-E102959.0600.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S103000-E105959.0630.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S110000-E112959.0660.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S113000-E115959.0690.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S120000-E122959.0720.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S123000-E125959.0750.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S130000-E132959.0780.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S133000-E135959.0810.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S140000-E142959.0840.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S143000-E145959.0870.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S150000-E152959.0900.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S153000-E155959.0930.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S160000-E162959.0960.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S163000-E165959.0990.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S170000-E172959.1020.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S173000-E175959.1050.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S180000-E182959.1080.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S183000-E185959.1110.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S190000-E192959.1140.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S193000-E195959.1170.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S200000-E202959.1200.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S203000-E205959.1230.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S210000-E212959.1260.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S213000-E215959.1290.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S220000-E222959.1320.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S223000-E225959.1350.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S230000-E232959.1380.V07B.HDF5',
#  'gesdisc-cumulus-prod-protected/GPM_L3/GPM_3IMERGHH.07/1998/001/3B-HHR.MS.MRG.3IMERG.19980101-S233000-E235959.1410.V07B.HDF5']

# %%
dsets = []

drop_variables = ["Intermediate", "nv", "lonv", "latv"]
all_coords = ["time", "lon", "lat", "time_bnds", "lon_bnds", "lat_bnds"]
min_coords = ["time", "time_bnds"]

for file in tqdm(one_day):
    url = f"s3://{file}"
    if len(dsets) == 0:
        my_drop_variables = drop_variables
        loadable_variables = all_coords
        my_coords = all_coords
    else:
        my_drop_variables = drop_variables + list(set(all_coords) - set(min_coords))
        loadable_variables = min_coords
        my_coords = min_coords
    ds = open_virtual_dataset(
        url, indexes={}, group="Grid", backend=HDFVirtualBackend,
        drop_variables=my_drop_variables,
        loadable_variables=loadable_variables
    ).set_coords(my_coords)
    dsets.append(ds)
# Out:
#   0%|          | 0/48 [00:00<?, ?it/s]

# %%
import xarray as xr
ds_concat = xr.concat(dsets, dim="time", coords="minimal", join="override")
ds_concat
# Out:
# <xarray.Dataset> Size: 4GB
# Dimensions:                         (time: 48, lon: 3600, lat: 1800, nv: 2,
#                                      lonv: 2, latv: 2)
# Coordinates:
#     time_bnds                       (time, nv) object 768B 1998-01-01 00:00:0...
#     lon_bnds                        (lon, lonv) float32 29kB ...
#     lat_bnds                        (lat, latv) float32 14kB ...
#   * time                            (time) object 384B 1998-01-01 00:00:00 .....
#   * lon                             (lon) float32 14kB -179.9 -179.9 ... 179.9
#   * lat                             (lat) float32 7kB -89.95 -89.85 ... 89.95
# Dimensions without coordinates: nv, lonv, latv
# Data variables:
#     precipitation                   (time, lon, lat) float32 1GB ManifestArra...
#     randomError                     (time, lon, lat) float32 1GB ManifestArra...
#     probabilityLiquidPrecipitation  (time, lon, lat) int16 622MB ManifestArra...
#     precipitationQualityIndex       (time, lon, lat) float32 1GB ManifestArra...
# Attributes:
#     GridHeader:  BinMethod=ARITHMETIC_MEAN;\nRegistration=CENTER;\nLatitudeRe...

# %% [markdown]
# ### Workaround for VirtualiZarr broken fill value encoding with zarr_format=3
#
# https://github.com/zarr-developers/VirtualiZarr/issues/343

# %%
from xarray.backends.zarr import FillValueCoder

coder = FillValueCoder()

# promote fill value to attr for zarr V3
for dvar in ds_concat.data_vars:
    dtype = ds_concat[dvar].dtype
    # this is wrong due to bug in Sean's reader
    #fill_value = dtype.type(ds_concat[dvar].data.zarray.fill_value)
    fill_value = dtype.type(ds_concat[dvar].attrs['CodeMissingValue'])
    encoded_fill_value = coder.encode(fill_value, dtype)
    ds_concat[dvar].attrs['_FillValue'] = encoded_fill_value
    print(dvar, dtype, fill_value, encoded_fill_value)

ds_concat
# Out:
# precipitation float32 -9999.9 AAAAQPOHw8A=
# randomError float32 -9999.9 AAAAQPOHw8A=
# probabilityLiquidPrecipitation int16 -9999 -9999
# precipitationQualityIndex float32 -9999.9 AAAAQPOHw8A=
# <xarray.Dataset> Size: 4GB
# Dimensions:                         (time: 48, lon: 3600, lat: 1800, nv: 2,
#                                      lonv: 2, latv: 2)
# Coordinates:
#     time_bnds                       (time, nv) object 768B 1998-01-01 00:00:0...
#     lon_bnds                        (lon, lonv) float32 29kB ...
#     lat_bnds                        (lat, latv) float32 14kB ...
#   * time                            (time) object 384B 1998-01-01 00:00:00 .....
#   * lon                             (lon) float32 14kB -179.9 -179.9 ... 179.9
#   * lat                             (lat) float32 7kB -89.95 -89.85 ... 89.95
# Dimensions without coordinates: nv, lonv, latv
# Data variables:
#     precipitation                   (time, lon, lat) float32 1GB ManifestArra...
#     randomError                     (time, lon, lat) float32 1GB ManifestArra...
#     probabilityLiquidPrecipitation  (time, lon, lat) int16 622MB ManifestArra...
#     precipitationQualityIndex       (time, lon, lat) float32 1GB ManifestArra...
# Attributes:
#     GridHeader:  BinMethod=ARITHMETIC_MEAN;\nRegistration=CENTER;\nLatitudeRe...

# %%
client = Client()
ic_repo = client.create_repo("nasa-impact/GPM_3IMERGHH.07-virtual", kind="icechunk")
ic_repo

# %%
ds_concat.virtualize.to_icechunk(ic_repo)
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/zarr/core/metadata/v3.py:79: UserWarning: Codec 'numcodecs.zlib' not configured in config. Selecting any implementation.
#   out += (get_codec_class(name_parsed).from_dict(c),)
# /srv/conda/envs/notebook/lib/python3.12/site-packages/numcodecs/zarr3.py:94: UserWarning: Numcodecs codecs are not in the Zarr version 3 specification and may not be supported by other zarr implementations.
#   warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/zarr/core/metadata/v3.py:79: UserWarning: Codec 'numcodecs.zlib' not configured in config. Selecting any implementation.
#   out += (get_codec_class(name_parsed).from_dict(c),)
# /srv/conda/envs/notebook/lib/python3.12/site-packages/numcodecs/zarr3.py:94: UserWarning: Numcodecs codecs are not in the Zarr version 3 specification and may not be supported by other zarr implementations.
#   warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/zarr/core/metadata/v3.py:79: UserWarning: Codec 'numcodecs.zlib' not configured in config. Selecting any implementation.
#   out += (get_codec_class(name_parsed).from_dict(c),)
# /srv/conda/envs/notebook/lib/python3.12/site-packages/numcodecs/zarr3.py:94: UserWarning: Numcodecs codecs are not in the Zarr version 3 specification and may not be supported by other zarr implementations.
#   warn(
# /srv/conda/envs/notebook/lib/python3.12/site-packages/zarr/core/metadata/v3.py:79: UserWarning: Codec 'numcodecs.zlib' not configured in config. Selecting any implementation.
#   out += (get_codec_class(name_parsed).from_dict(c),)
# /srv/conda/envs/notebook/lib/python3.12/site-packages/numcodecs/zarr3.py:94: UserWarning: Numcodecs codecs are not in the Zarr version 3 specification and may not be supported by other zarr implementations.
#   warn(

# %%
ic_repo.commit("wrote virtual dataset")
# Out:
# 'ANYB3BTF2ZF6ANR5FFZ0'
